# %% [markdown]
# # Matplotlib
# Read the links https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before starting the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %% [raw]
# There are two ways to create plots in Matplotlib:
# Pyplot (state-based) interface
# This is the simpler style where you call functions like plt.plot(...), plt.title(...), etc.
#
# Object-oriented (OO) interface
# This uses explicit Figure and Axes objects.
#
# The recommended way (especially for more complex plots) is the object-oriented interface because it gives you better control over the plot structure and is more consistent for advanced plotting.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %% [raw]
# Figure
# The figure is the entire window or canvas that contains one or more plots.
# Axes
# An axes is the area where the data is actually plotted (the plot itself). A figure can contain multiple axes.
# Axis
# An axis refers to a single coordinate axis (x-axis or y-axis) that controls ticks, labels, and scale.
# Artist
# An artist is any visible element in a figure, such as lines, text, labels, legends, or markers. Everything drawn in Matplotlib is an artist.

# %% [raw]
# ### When plotting in Matplotlib, what is the expected input data type?

# %% [raw]
# When plotting in Matplotlib, the expected input data type is array-like data, such as:
# Python lists
# NumPy arrays
# Pandas Series or DataFrames
#
# Most commonly, NumPy arrays are used, since Matplotlib is designed to work closely with NumPy.

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4, 4, 100)
y = x**2
plt.plot(x, y)
plt.title("y = x² (Pyplot approach)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("y = x² (Object-oriented approach)")
ax.set_xlabel("x")
ax.set_ylabel("y")
plt.show()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))  # 1 row, 2 columns

# Scatter plot
ax1.scatter(random_data_x, random_data_y, color='blue', alpha=0.5)
ax1.set_title("Scatter Plot")
ax1.set_xlabel("X values")
ax1.set_ylabel("Y values")

# Bar plot
ax2.bar(names, values, color='orange')
ax2.set_title("Bar Plot of Fruit Data")
ax2.set_xlabel("Fruits")
ax2.set_ylabel("Quantity")

# Adjust layout so titles/labels don't overlap
plt.tight_layout()

# Show the figure
plt.show()
